# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
heart_dataset = pd.read_csv("D:\prediction of disease outbreak\datasets\heart.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\bolla\AppData\Local\Temp\ipykernel_11412\2896037700.py:1: SyntaxWarning: invalid escape sequence '\p'
#   heart_dataset = pd.read_csv("D:\prediction of disease outbreak\datasets\heart.csv")

# %%
heart_dataset.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_dataset.shape
# Out:
# (303, 14)

# %%
heart_dataset.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
heart_dataset['target'].value_counts()
# Out:
# target
# 1    165
# 0    138
# Name: count, dtype: int64

# %%
heart_dataset.groupby('target').mean()
# Out:
#               age       sex        cp    trestbps        chol       fbs  \
# target
# 0       56.601449  0.826087  0.478261  134.398551  251.086957  0.159420
# 1       52.496970  0.563636  1.375758  129.303030  242.230303  0.139394
#
#          restecg     thalach     exang   oldpeak     slope        ca      thal
# target
# 0       0.449275  139.101449  0.550725  1.585507  1.166667  1.166667  2.543478
# 1       0.593939  158.466667  0.139394  0.583030  1.593939  0.363636  2.121212

# %%
X = heart_dataset.drop(columns=['target'],axis=1)
y = heart_dataset['target']

# %%
X.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal
# 0   0     1
# 1   0     2
# 2   0     2
# 3   0     2
# 4   0     2

# %%
X_train, X_test, Y_train, Y_test =train_test_split(X,y,test_size=0.2,random_state=2)

# %%
X_train.head()
# Out:
#      age  sex  cp  trestbps  chol  ...  exang  oldpeak  slope  ca  thal
# 237   60    1   0       140   293  ...      0      1.2      1   2     3
# 106   69    1   3       160   234  ...      0      0.1      1   1     2
# 10    54    1   0       140   239  ...      0      1.2      2   0     2
# 153   66    0   2       146   278  ...      0      0.0      1   1     2
# 77    59    1   1       140   221  ...      1      0.0      2   0     2
#
# [5 rows x 13 columns]

# %%
X_test.shape
# Out:
# (61, 13)

# %%
model =svm.SVC(kernel='linear')

# %%
model.fit(X_train,Y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = model.predict(X_test)

# %%
print(accuracy_score(Y_test,y_pred))
# Out:
# 0.8688524590163934

# %%
pip install pickle
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement pickle (from versions: none)
# ERROR: No matching distribution found for pickle

# %%
import pickle
filename = 'heart_model_sav'
pickle.dump(model, open(filename, 'wb'))

# %%
loaded_model =pickle.load(open('heart_model_sav', 'rb'))

# %%
input_data = (42,1,0,140,226,0,1,178,0,0,2,0,2,1)

#change the input _data to numpy array
input_data_as_numpy_array = np.asarray(input_data)

#reshape the array as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = loaded_model.predict(input_data_reshaped)
print(prediction)

if (prediction[0] == 0):
    print('The person is not attacked')
else:
    print('The person is attacked')
# Out:
# c:\Users\bolla\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 9
#       6 #reshape the array as we are predicting for one instance
#       7 input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)
# ----> 9 prediction = loaded_model.predict(input_data_reshaped)
#      10 print(prediction)
#      12 if (prediction[0] == 0):
#
# File c:\Users\bolla\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\svm\_base.py:822, in BaseSVC.predict(self, X)
#     820     y = np.argmax(self.decision_function(X), axis=1)
#     821 else:
# --> 822     y = super().predict(X)
#     823 return self.classes_.take(np.asarray(y, dtype=np.intp))
#
# ...

# %%
for column in X.columns:
    print (column)
# Out:
# age
# sex
# cp
# trestbps
# chol
# fbs
# restecg
# thalach
# exang
# oldpeak
# slope
# ca
# thal
